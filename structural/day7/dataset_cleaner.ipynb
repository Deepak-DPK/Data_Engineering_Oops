# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("employees.csv")

# %%
df
# Out:
#       name   salary department   age
# 0    Alice  50000.0         HR  25.0
# 1      Bob  60000.0         IT  30.0
# 2  Charlie      NaN         IT  35.0
# 3    David  45000.0        NaN  22.0
# 4      Eve  70000.0         HR   NaN

# %%
df_filled = df.fillna({
    "department":"Unassinged"
})

# %%
df_filled
# Out:
#       name   salary  department   age
# 0    Alice  50000.0          HR  25.0
# 1      Bob  60000.0          IT  30.0
# 2  Charlie      NaN          IT  35.0
# 3    David  45000.0  Unassinged  22.0
# 4      Eve  70000.0          HR   NaN

# %%
df_clean = df_filled.dropna()

# %%
df_clean
# Out:
#     name   salary  department   age
# 0  Alice  50000.0          HR  25.0
# 1    Bob  60000.0          IT  30.0
# 3  David  45000.0  Unassinged  22.0
