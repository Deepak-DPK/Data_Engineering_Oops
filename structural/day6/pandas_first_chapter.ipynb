# %%
import pandas as pd

# %%
data = {
    "product": ["Laptop", "Mouse", "Monitor", "Keyboard", "Webcam"],
    "price": [1000, 25, 200, 50, 80],
    "stock": [5, 100, 10, 30, 15]
}

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#     product  price  stock
# 0    Laptop   1000      5
# 1     Mouse     25    100
# 2   Monitor    200     10
# 3  Keyboard     50     30
# 4    Webcam     80     15

# %%
df.head(4)
# Out:
#     product  price  stock
# 0    Laptop   1000      5
# 1     Mouse     25    100
# 2   Monitor    200     10
# 3  Keyboard     50     30

# %%
df.shape
# Out:
# (5, 3)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   product  5 non-null      object
#  1   price    5 non-null      int64
#  2   stock    5 non-null      int64
# dtypes: int64(2), object(1)
# memory usage: 252.0+ bytes

# %%
df["product"]
# Out:
# 0      Laptop
# 1       Mouse
# 2     Monitor
# 3    Keyboard
# 4      Webcam
# Name: product, dtype: object

# %%
df[["product", "price"]]
# Out:
#     product  price
# 0    Laptop   1000
# 1     Mouse     25
# 2   Monitor    200
# 3  Keyboard     50
# 4    Webcam     80

# %%
high_stocks = df[ df["stock"]  > 20 ]
high_stocks
# Out:
#     product  price  stock
# 1     Mouse     25    100
# 3  Keyboard     50     30

# %%
#TASK

# %%
expensive_df = df[ df["price"] > 50]
expensive_df
# Out:
#    product  price  stock
# 0   Laptop   1000      5
# 2  Monitor    200     10
# 4   Webcam     80     15

# %%
df["tax"] = df["price"] * 0.10
df
# Out:
#     product  price  stock    tax
# 0    Laptop   1000      5  100.0
# 1     Mouse     25    100    2.5
# 2   Monitor    200     10   20.0
# 3  Keyboard     50     30    5.0
# 4    Webcam     80     15    8.0

# %%
df["total_value"] = df["price"]  * df["stock"]
df
# Out:
#     product  price  stock    tax  total_value
# 0    Laptop   1000      5  100.0         5000
# 1     Mouse     25    100    2.5         2500
# 2   Monitor    200     10   20.0         2000
# 3  Keyboard     50     30    5.0         1500
# 4    Webcam     80     15    8.0         1200

# %%
df.head(1)
# Out:
#   product  price  stock    tax  total_value
# 0  Laptop   1000      5  100.0         5000

# %%
df.to_csv("inventory_report.csv", index=False)

# %%
exit
