# %%
import pandas as pd

# %%
data = {
    "name":["shikamaru", "choji", "temari", "kushina", "minato"],
    "age":[22, 24, 22, 54, 52],
    "relationship_type":["me", "brother", "Girlfriend", "mom","dad"]
}

df =pd.DataFrame(data)
df
# Out:
#         name  age relationship_type
# 0  shikamaru   22                me
# 1      choji   24           brother
# 2     temari   22        Girlfriend
# 3    kushina   54               mom
# 4     minato   52               dad

# %%
df[df["age"]>22]
# Out:
#       name  age relationship_type
# 1    choji   24           brother
# 3  kushina   54               mom
# 4   minato   52               dad

# %%
df["Maturity"] = (df["age"] > 18)
df
# Out:
#         name  age relationship_type  Maturity
# 0  shikamaru   22                me      True
# 1      choji   24           brother      True
# 2     temari   22        Girlfriend      True
# 3    kushina   54               mom      True
# 4     minato   52               dad      True

# %%
df["age"]
# Out:
# 0    22
# 1    24
# 2    22
# 3    54
# 4    52
# Name: age, dtype: int64

# %%
df["name"],df["age"]
# Out:
# (0    shikamaru
#  1        choji
#  2       temari
#  3      kushina
#  4       minato
#  Name: name, dtype: object,
#  0    22
#  1    24
#  2    22
#  3    54
#  4    52
#  Name: age, dtype: int64)

# %%
average_age = df["age"].mean()
average_age
# Out:
# np.float64(34.8)
