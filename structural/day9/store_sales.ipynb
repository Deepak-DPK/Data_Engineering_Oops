# %%
import pandas as pd


data = {
    "date": ["2026-01-01", "2026-01-01", "2026-01-02", "2026-01-02"],
    "store_id": [101, 102, 101, 102],
    "sales": [500, 300, 550, 320],
    "customers": [50, 30, 55, 32]
}

# Saving it to your hard drive
pd.DataFrame(data).to_csv("store_sales.csv", index=False)
print("File Created Successfully!")
# Out:
# File Created Successfully!

# %%
df_sales = pd.read_csv("store_sales.csv")

# %%
df_sales.shape
# Out:
# (4, 4)

# %%
df_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   date       4 non-null      object
#  1   store_id   4 non-null      int64
#  2   sales      4 non-null      int64
#  3   customers  4 non-null      int64
# dtypes: int64(3), object(1)
# memory usage: 260.0+ bytes
